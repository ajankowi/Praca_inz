# %%
import tensorflow as tf
import numpy as np

import matplotlib.pyplot as plt

print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.1.0

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[ 0.57487098, -0.17752694, -0.28581678, -0.2440972 , -0.56196333]])

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.05094993, 0.09283284, 0.04974454, 0.12697486, 0.10034276,
#         0.09102271, 0.09153366, 0.05682277, 0.12175774, 0.2180182 ]])

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
loss_fn(y_train[:1], predictions).numpy()
# Out:
# 2.39664626121521

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
fit_result = model.fit(x_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.2992 - accuracy: 0.9132
# Epoch 2/5
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.1467 - accuracy: 0.9566
# Epoch 3/5
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.1089 - accuracy: 0.9671
# Epoch 4/5
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0894 - accuracy: 0.9720
# Epoch 5/5
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.0772 - accuracy: 0.9756

# %%
plt.plot(fit_result.history['loss'], label='loss')
plt.plot(fit_result.history['accuracy'], label='accuracy')
plt.legend()

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 10000/10000 - 0s - loss: 0.0801 - accuracy: 0.9761
# [0.08014251096980343, 0.9761]

# %%
probability_model = tf.keras.Sequential([
  model,
  tf.keras.layers.Softmax()
])

# %%
arr = probability_model(x_test[:20])

# %%
for x in range(len(arr)):
    value_old = 0
    for i in range(len(arr[x])): 
        
        tens = arr[x][i]
        
        
        
        if tens > value_old:
            var = i
            value = tens
            value_old = tens
            
 
    sample_image = np.array(x_test[x]) 
    sample_image = sample_image.reshape(28,28)
    plt.figure(figsize=(2,2))
    plt.axis('off')
    plt.title('Wyznaczona wartosc: {} \n Accuracy: {}'.format(var,value))
    plt.imshow(sample_image, cmap = 'gray')

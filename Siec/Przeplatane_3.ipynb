# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.8.2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os
import csv
import random

import cv2
import imutils
import glob
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
#Określenie ścieżek do plików
folder = '../../Dane/Baza_zdjec_przeplatane_1/'
nazwa_CSV = 'nowe.csv'
folder_2 = '../../Dane/Baza_zdjec_moje/'
przed = 'Przed/'
zlaczone = 'Zlaczone/'
slesh = '/'
png = '.png'

# %%
def release_list(a):
    
    del a[:]
    del a

# %%
#Wczytanie pliku CSV do tablicy images

with open(folder+nazwa_CSV,"r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))

    
value = []
for i in new[0]:
    value.append(int(i))    
    
print(len(value))
# Out:
# 3600

# %%
#Wczytanie zdjęć do tablicy images
images = []
size = len(value)

for i in range(size):
    im = Image.open(folder+str(i)+png)
    arr_im = np.array(im) 
    arr_im = arr_im / 255.0
    images.append(arr_im) 
print(len(images))
# Out:
# 3600

# %%
#Inicjalizacja tablic
rand_list = []
rand_list = np.zeros((len(images)), dtype=np.uint8)

x_test = []
y_test = []

x_train = []
y_train = []


#Okreslanie wielkosci zbiorów
eighty = int(len(images)*80/100)
twenty = len(images) - eighty

#Losowanie zbioru testowego
for i in range(eighty):
    
    #Pierwsze losowanie wartości
    rand = random.randint(0,len(images)-1)
    
    #Sprawdzenie czy wylosowana wartość się powtarza
    while (rand_list[rand] == 1) :
        #Jeżeli tak to ponownie losuje
        rand = random.randint(0,len(images)-1)
    
    #Zapisanie zdjecia i wartości do nowej tablicy
    x_train.append(images[rand])
    y_train.append(value[rand])
    rand_list[rand] = 1

#Losowanie zbioru uczącego
for j in range(twenty):
    
    #Pierwsze losowanie wartości
    rand = random.randint(0,len(images)-1)
    
    #Sprawdzenie czy wylosowana wartość się powtarza
    while (rand_list[rand] == 1) :
        #Jeżeli tak to ponownie losuje
        rand = random.randint(0,len(images)-1)
        
    #Zapisanie zdjecia i wartości do nowej tablicy
    x_test.append(images[rand])
    y_test.append(value[rand])
    rand_list[rand] = 1
    
release_list(images)
release_list(value)

# %%
#Sprawdzenie poprawności losowania
val_1 = sum(y_test) / 1800
print("%.2f" % val_1 + '%') 


val_2 = sum(y_train) / 1800
print("%.2f" % val_2 + '%')
# Out:
# 0.21%
# 0.79%

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)

y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
plt.imshow(x_train[0],cmap = 'gray')
print(x_train[0])
# Out:
# [[0.408 0.412 0.353 ... 0.404 0.4   0.4  ]
#  [0.412 0.4   0.314 ... 0.404 0.404 0.4  ]
#  [0.42  0.384 0.278 ... 0.404 0.404 0.404]
#  ...
#  [0.271 0.275 0.267 ... 0.31  0.314 0.31 ]
#  [0.275 0.278 0.275 ... 0.306 0.31  0.306]
#  [0.271 0.275 0.271 ... 0.298 0.306 0.302]]

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))
# Out:
# 2022-12-06 23:22:28.749116: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-06 23:22:28.751921: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 62, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 63, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 14, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 12, 64)        36928
#
#  flatten (Flatten)           (None, 21504)             0
#
#  dense (Dense)               (None, 64)                1376320
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,432,714
# Trainable params: 1,432,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Funcka umożliwia zatrzymanie się uczenia 
#gdy wartość strat przstanie maleć
EarlyStop = EarlyStopping(monitor='val_loss', 
                          patience=3,
                          verbose=1)

history = model.fit(x_train, 
                    y_train, 
                    epochs=20, 
                    validation_data=(x_test, y_test),
                    callbacks = [EarlyStop]
                   )
# Out:
# Epoch 1/20
# 90/90 [==============================] - 31s 345ms/step - loss: 0.3925 - accuracy: 0.8003 - val_loss: 0.1948 - val_accuracy: 0.9319
# Epoch 2/20
# 90/90 [==============================] - 30s 337ms/step - loss: 0.1040 - accuracy: 0.9556 - val_loss: 0.0192 - val_accuracy: 0.9958
# Epoch 3/20
# 90/90 [==============================] - 32s 359ms/step - loss: 0.0145 - accuracy: 0.9965 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 4/20
# 90/90 [==============================] - 31s 343ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 5/20
# 90/90 [==============================] - 32s 360ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 6/20
# 90/90 [==============================] - 35s 391ms/step - loss: 6.6689e-04 - accuracy: 1.0000 - val_loss: 4.0559e-04 - val_accuracy: 1.0000
# Epoch 7/20
# 90/90 [==============================] - 33s 371ms/step - loss: 3.1670e-04 - accuracy: 1.0000 - val_loss: 2.2480e-04 - val_accuracy: 1.0000
# Epoch 8/20
# 90/90 [==============================] - 36s 396ms/step - loss: 2.1172e-04 - accuracy: 1.0000 - val_loss: 1.6565e-04 - val_accuracy: 1.0000
# Epoch 9/20
# 90/90 [==============================] - 36s 396ms/step - loss: 1.5003e-04 - accuracy: 1.0000 - val_loss: 1.6333e-04 - val_accuracy: 1.0000
# Epoch 10/20
# 90/90 [==============================] - 32s 359ms/step - loss: 1.2005e-04 - accuracy: 1.0000 - val_loss: 1.3003e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 90/90 [==============================] - 36s 395ms/step - loss: 8.4347e-05 - accuracy: 1.0000 - val_loss: 8.6007e-05 - val_accuracy: 1.0000
# Epoch 12/20
# 90/90 [==============================] - 32s 352ms/step - loss: 6.8600e-05 - accuracy: 1.0000 - val_loss: 7.2624e-05 - val_accuracy: 1.0000
# Epoch 13/20
# 90/90 [==============================] - 34s 379ms/step - loss: 5.8796e-05 - accuracy: 1.0000 - val_loss: 8.7472e-05 - val_accuracy: 1.0000
# Epoch 14/20
# 90/90 [==============================] - 32s 353ms/step - loss: 4.6756e-05 - accuracy: 1.0000 - val_loss: 6.5157e-05 - val_accuracy: 1.0000
# Epoch 15/20
# 90/90 [==============================] - 33s 371ms/step - loss: 3.9228e-05 - accuracy: 1.0000 - val_loss: 4.6513e-05 - val_accuracy: 1.0000
# Epoch 16/20
# 90/90 [==============================] - 36s 402ms/step - loss: 3.2778e-05 - accuracy: 1.0000 - val_loss: 4.1012e-05 - val_accuracy: 1.0000
# Epoch 17/20
# 90/90 [==============================] - 36s 395ms/step - loss: 2.7266e-05 - accuracy: 1.0000 - val_loss: 4.2633e-05 - val_accuracy: 1.0000
# Epoch 18/20
# 90/90 [==============================] - 36s 397ms/step - loss: 2.2742e-05 - accuracy: 1.0000 - val_loss: 3.3397e-05 - val_accuracy: 1.0000
# Epoch 19/20
# 90/90 [==============================] - 33s 365ms/step - loss: 1.9728e-05 - accuracy: 1.0000 - val_loss: 2.6055e-05 - val_accuracy: 1.0000
# Epoch 20/20
# 90/90 [==============================] - 32s 350ms/step - loss: 1.5967e-05 - accuracy: 1.0000 - val_loss: 2.7636e-05 - val_accuracy: 1.0000

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 0.5])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 23/23 - 2s - loss: 2.7636e-05 - accuracy: 1.0000 - 2s/epoch - 99ms/step

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 23/23 - 2s - loss: 2.7636e-05 - accuracy: 1.0000 - 2s/epoch - 93ms/step

# %%
print(test_acc)
# Out:
# 1.0

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 23/23 - 2s - loss: 2.7636e-05 - accuracy: 1.0000 - 2s/epoch - 94ms/step
# [2.7636117524960153e-05, 1.0]

# %%
probability_model = tf.keras.Sequential([
  model,
  tf.keras.layers.Softmax()
])

# %%
arr = probability_model(x_test)

# %%
ok = 0
wrong = 0
err = 0

arr_2 = []

for x in range(len(arr)):
    
    maks = 0
    for i in range(10): 
        
        if arr[x][i] > arr[x][maks]:
              maks = i
                
    if maks == 0 :
        arr_2.append(0)
        
        if maks == y_test[x] :
            ok = ok + 1          
        else:
            wrong = wrong + 1
            
            
    if maks == 1 :
        arr_2.append(1)
        if maks == y_test[x] :
            ok = ok + 1        
        else:
            wrong = wrong + 1       
    
    
    if maks > 2 :
        err = err + 1
        print(x)


print(ok) 
print(wrong) 
print(err)
# Out:
# 720
# 0
# 0

# %%
names = [['Tn','Nn'],['Np', 'Tp']]
names = np.reshape(names,(2,2))
print(names)

tf.math.confusion_matrix(y_test,arr_2)
# Out:
# [['Tn' 'Nn']
#  ['Np' 'Tp']]
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[337,   0],
#        [  0, 383]], dtype=int32)>

# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os

import cv2
import imutils

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
folder = 'Baza_zdjec/s'
folder_docelowy = 'Baza_zdjec_przerobiona/s'
slesh = '/'
png = '.png'

# %%
im = cv2.imread(folder_docelowy+str(10)+slesh+str(7)+png)
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
print(im)
# Out:
# [[135 135 130 ... 128 130 130]
#  [135 129 119 ... 126 128 127]
#  [134 126 109 ... 128 128 128]
#  ...
#  [ 26  33  32 ...  23  19  36]
#  [ 33  34  30 ...  23  16  37]
#  [ 35  27  28 ...  20  20  39]]

# %%
im = im/255
plt.imshow(im, cmap = 'gray')

# %%
mean = 0
var = 0.01
sigma = np.sqrt(var)


n = np.random.normal(mean,sigma,size=(64,64))

# %%
print(n)
# Out:
# [[ 0.059  0.042 -0.06  ... -0.002  0.031  0.156]
#  [-0.025 -0.119 -0.131 ... -0.153  0.03   0.131]
#  [ 0.062 -0.008 -0.089 ... -0.158  0.006  0.097]
#  ...
#  [-0.079  0.063  0.123 ... -0.045 -0.069 -0.032]
#  [ 0.039 -0.122 -0.028 ... -0.035 -0.096 -0.022]
#  [ 0.094 -0.12  -0.026 ...  0.027 -0.08  -0.042]]

# %%
g = im + n

# %%
plt.imshow(g, cmap = 'gray')
g = g * 255

# %%
cv2.imwrite(folder_docelowy+str(10)+slesh+str(71)+png, g)
# Out:
# True

# %%
image = cv2.imread(folder_docelowy+str(10)+slesh+str(71)+png) 
plt.imshow(image, cmap = 'gray')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(image)
# Out:
# [[150 146 115 ... 127 138 170]
#  [129  99  86 ...  87 136 160]
#  [150 124  86 ...  88 129 153]
#  ...
#  [  6  49  63 ...  12   1  28]
#  [ 43   3  23 ...  14   0  32]
#  [ 59   0  21 ...  27   0  28]]

# %%
mean = 0
var = 0.01
sigma = np.sqrt(var)

# %%
#Wczytanie obrazu
im = cv2.imread()

# %%
#Wlasciwa czesc kodu

mean = 0
var = 0.01
sigma = np.sqrt(var)

        
#Wczytanie obrazu
im = cv2.imread(folder_docelowy+str(i)+slesh+str(j)+png)
        
#Konwersja zdjec na czarno - biale
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        
#Zmiana wartosci na skale od 0 do 1
im = im/255
        
#Tworzenie szumu
n = np.random.normal(mean,sigma,size=(64,64))
        
#Dodanie szumu do obrazu
g = im + n
        
#Zmaiana wartosci na skale od 0 do 255
g = g * 255
        
#Zapisanie zmienionego zdjecia
#cv2.imwrite(folder_docelowy+str(i)+slesh+str(j+70)+png, g)

# %%
twarz = cv2.imread('twarz.jpg')
twarz = cv2.cvtColor(twarz, cv2.COLOR_BGR2GRAY)

# %%
twarz = cv2.imread('twarz.jpg')
twarz = cv2.cvtColor(twarz, cv2.COLOR_BGR2GRAY)

mean = 0
var = 0.01
sigma = np.sqrt(var)


#Zmiana wartosci na skale od 0 do 1
img = twarz/255
        
#Tworzenie szumu
n = np.random.normal(mean,sigma,size=(843,1500))
        
#Dodanie szumu do obrazu
g = img + n

g = g*255

# %%
plt.imshow(g, cmap = 'gray')
# Out:
# (843, 1500)

# %%
plt.imshow(twarz, cmap = 'gray')

# %%
print(g)
# Out:
# [[ 65.918  60.027  86.12  ... 127.514  69.687  86.148]
#  [ 64.94   67.391  78.542 ...  93.134 112.715 102.405]
#  [ 93.627  80.125  89.789 ...  99.206 132.614 105.653]
#  ...
#  [102.892 103.755 115.281 ... 143.827 137.572 125.622]
#  [ 62.418  62.196 128.044 ... 132.076 164.368 143.304]
#  [ 80.281 126.825 107.232 ... 150.21  106.525 119.499]]

# %%
print(twarz)
# Out:
# [[ 80  90  93 ... 112 110 109]
#  [ 80  90  94 ... 110 109 110]
#  [ 79  90  96 ... 111 111 113]
#  ...
#  [ 80  88  98 ... 123 122 121]
#  [ 79  88  98 ... 123 123 122]
#  [ 78  88  99 ... 122 123 123]]

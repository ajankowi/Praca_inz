# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
twarz = Image.open('Baza_zdjec/s4/1.pgm')

# %%
szer, wyso = twarz.size

# %%
print(twarz.size)
plt.imshow(twarz, cmap = 'gray')
# Out:
# (92, 112)

# %%
arr_twarz = np.array(twarz)

# %%
print(arr_twarz)
# Out:
# [[115 113 113 ... 111 110 110]
#  [114 117 114 ... 108 112 109]
#  [116 116 117 ... 106 113 112]
#  ...
#  [ 99  96 101 ...  52  58  49]
#  [ 93 101  94 ...  52  51  57]
#  [ 99  93 101 ...  56  52  55]]

# %%
w, h = 92, 92
data = np.zeros((h, w), dtype=np.uint8)
data[0:w, 0:w] = [255]

# %%
for x in range(w):
    data[x] = arr_twarz[10+x]

# %%
con = Image.fromarray(data)

# %%
plt.imshow(con, cmap = 'gray')

# %%
con_2 = con.resize((int(64), int(64)))
plt.imshow(con_2, cmap = 'gray')

# %%
newpath = r'Baza_zdjec_przerobiona/s4' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
con_2.save(r'Baza_zdjec_przerobiona/s4/1.png')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 os.makedirs('Baza_zdjec_przerobiona/s4')
#       2 con_2.save(r'Baza_zdjec_przerobiona/s4/1.png')
#
# File ~/anaconda3/envs/py39/lib/python3.9/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: 'Baza_zdjec_przerobiona/s4'

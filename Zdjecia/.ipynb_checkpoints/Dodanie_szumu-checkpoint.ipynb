# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os

import cv2
import imutils

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
folder = 'Baza_zdjec/s'
folder_docelowy = 'Baza_zdjec_przerobiona/s'
slesh = '/'
png = '.png'

# %%
im = cv2.imread(folder_docelowy+str(10)+slesh+str(7)+png)
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
im = im/255
plt.imshow(im, cmap = 'gray')

# %%
print(im)

# %%
mean = 0
var = 0.01
sigma = np.sqrt(var)


n = np.random.normal(mean,sigma,size=(64,64))

# %%
print(n)
# Out:
# [[ 0.005 -0.19   0.17  ... -0.105 -0.037 -0.003]
#  [ 0.153 -0.068  0.036 ...  0.003 -0.088  0.035]
#  [ 0.056  0.093  0.071 ...  0.041 -0.069  0.111]
#  ...
#  [ 0.135  0.125 -0.056 ...  0.041  0.079  0.069]
#  [ 0.029 -0.072  0.035 ... -0.112 -0.018 -0.109]
#  [-0.169 -0.071 -0.088 ...  0.209 -0.007 -0.112]]

# %%
g = im + n

# %%
plt.imshow(g, cmap = 'gray')
g = g * 255

# %%
cv2.imwrite(folder_docelowy+str(10)+slesh+str(71)+png, g)
# Out:
# True

# %%
image = cv2.imread(folder_docelowy+str(10)+slesh+str(71)+png) 
plt.imshow(image, cmap = 'gray')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(image)
# Out:
# [[136  87 173 ... 101 121 129]
#  [174 112 128 ... 127 106 136]
#  [148 150 127 ... 139 111 156]
#  ...
#  [ 60  65  18 ...  33  39  54]
#  [ 40  16  39 ...   0  11   9]
#  [  0   9   6 ...  73  18  11]]

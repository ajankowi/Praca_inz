# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
folder = 'Baza_zdjec/s'
folder_docelowy = 'Baza_zdjec_przerobiona/s'
slesh = '/'
pgm = '.pgm'
png = '.png'

# %%
#Wlasciwa czesc kodu
w, h = 92, 92

for i in range(1,41):
    for j in range(1,11):
        im = Image.open(folder+str(i)+slesh+str(j)+pgm)
        im_arr = np.array(im)
        
        #Tworzenie pustej tablicy
        data = np.zeros((h, w), dtype=np.uint8)
        data[0:w, 0:w] = [255]
        
        #Kopiowanie 92 wierszy (kwadratowy obraz)
        for x in range(w):
            data[x] = im_arr[10+x]
        
        #konwersja tablicy znaków na obraz
        con = Image.fromarray(data)

        #Zmiana rozmiaru zdjec
        con_2 = con.resize((int(64), int(64)))
        
        #Stworzenie nowego katalogu
        newpath = folder_docelowy+str(i)
        if not os.path.exists(newpath):
            os.makedirs(newpath)
            
        #Zapisanie zmienionego zdjecia
        con_2.save(newpath+slesh+str(j)+png)

# %%
#Stare

newpath = r'Baza_zdjec_przerobiona/s4' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
else:
    print("Juz istnieje folder!")
con_2.save(r'Baza_zdjec_przerobiona/s4/1.png')
# Out:
# Juz istnieje folder!

# %%
#Stare

people_list = []

for i in range(1,41):
    image_list = []
    for j in range(1,11):
        im = Image.open(folder+str(i)+slesh+str(j)+pgm)
        image_list.append(im)
    people_list.append(image_list)

# %%
#Stare

print(image_list[1].size)
plt.imshow(image_list[1], cmap = 'gray')
# Out:
# (92, 112)

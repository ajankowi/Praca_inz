# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os

import cv2
import imutils

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
folder = 'Baza_zdjec/s'
folder_docelowy = 'Baza_zdjec_przerobiona/s'
slesh = '/'
pgm = '.pgm'
png = '.png'

# %%
im = Image.open(folder_docelowy+str(10)+slesh+str(2)+png)

# %%
plt.imshow(im, cmap = 'gray')

# %%
rotated_image1 = im.rotate(6)

# %%
plt.imshow(rotated_image1, cmap = 'gray')

# %%
im_2 = Image.open('000254.jpg')

# %%
plt.imshow(im_2, cmap = 'gray')

# %%
rotated_image2 = im_2.rotate(5)

# %%
plt.imshow(rotated_image2, cmap = 'gray')

# %%
image = cv2.imread(folder_docelowy+str(10)+slesh+str(2)+png)

# %%
plt.imshow(image, cmap = 'gray')

# %%
rot = imutils.rotate(image, angle=-6)

# %%
plt.imshow(rot, cmap = 'gray')

# %%
cv2.imwrite(folder_docelowy+str(10)+slesh+str(11)+png, rot)
# Out:
# True

# %%
im_arr = np.array(rot)

# %%
gray = cv2.cvtColor(im_arr, cv2.COLOR_BGR2GRAY)

# %%
print(gray)
# Out:
# [[  0   0   0 ... 125 112   0]
#  [121 126 131 ... 125 116   0]
#  [134 132 136 ... 123 119   0]
#  ...
#  [  0  36  22 ...  19  23  25]
#  [  0  24  19 ...  17  23  20]
#  [  0  19  20 ...   0   0   0]]

# %%
cv2.imwrite(folder_docelowy+str(10)+slesh+str(11)+png, gray)
# Out:
# True

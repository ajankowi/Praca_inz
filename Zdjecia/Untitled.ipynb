# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.8.2

# %%
import imageio as iio

im = iio.imread('1_1.png')
print(im.shape)
# Out:
# (92, 92, 4)

# %%
#im = im.reshape(28,28)
#print(im.shape)
#plt.figure(figsize=(2,2))
#plt.axis('off')
#plt.title('Wyznaczona wartosc: {} \n Accuracy: {:.4f}'.format(var,value))
#plt.imshow(sample_image, cmap = 'gray')

# %%
from PIL import Image

twarz = Image.open('1_prost.png')

# %%
szer, wyso = twarz.size

# %%
maly = twarz.resize((int(92), int(92)))

# %%
print(twarz.size)
plt.imshow(twarz, cmap = 'gray')
# Out:
# (92, 112)

# %%
print(maly.size)
plt.imshow(maly, cmap = 'gray')
# Out:
# (92, 92)

# %%
from PIL import Image

twarz_2 = Image.open('1_1.png')
print(twarz_2.size)
plt.imshow(twarz_2, cmap = 'gray')
# Out:
# (92, 92)

# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 11:38:51)
# [GCC 7.5.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
twarz = Image.open('../../Dane/Baza_aktorzy/1/1.jpg').convert('L')

# %%
szer, wyso = twarz.size

# %%
print(twarz.size)
plt.imshow(twarz, cmap = 'gray')
# Out:
# (178, 218)

# %%
arr_twarz = np.array(twarz)

# %%
print(arr_twarz)
# Out:
# [[ 89  89  89 ... 232 233 233]
#  [ 89  89  89 ... 232 233 233]
#  [ 89  89  89 ... 232 233 233]
#  ...
#  [243 242 241 ... 233 236 236]
#  [241 242 241 ... 233 236 236]
#  [241 242 241 ... 233 236 236]]

# %%
w, h = 178, 92
data = np.zeros((h, w), dtype=np.uint8)
data[0:h, 0:w] = [255]

# %%
for x in range(h):
    data[x] = arr_twarz[85+x]

# %%
con = Image.fromarray(data)

# %%
plt.imshow(con, cmap = 'gray')

# %%
width, height = twarz.size

x = 92
y = 92

# Setting the points for cropped image
left = 43
top = height / 4
right = 135
bottom = 3 * height / 4

im1 = twarz.crop((left, top, right, bottom))

# %%
print(twarz)
print(im1)
# Out:
# <PIL.Image.Image image mode=L size=178x218 at 0x7F7CA84D3280>
# <PIL.Image.Image image mode=L size=92x110 at 0x7F7C076F6040>

# %%
plt.imshow(im1, cmap = 'gray')

# %%
con_2 = con.resize((int(64), int(64)))
plt.imshow(con_2, cmap = 'gray')

# %%
newpath = r'Baza_zdjec_przerobiona/s4' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
con_2.save(r'Baza_zdjec_przerobiona/s4/1.png')
